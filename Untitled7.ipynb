# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
from sklearn.model_selection import cross_validate
from sklearn.model_selection import cross_val_score
from sklearn import preprocessing

# %%
train_df = pd.read_csv('train.csv', header=0)
train_y = train_df['SalePrice']

# %%
train_df.drop('Id',axis=1,inplace=True)
train_df.drop('SalePrice',axis=1,inplace=True)

# %%
features = train_df.columns.values
consider = []
numerics = ['LotArea','LotFrontage','YearBuilt','YearRemodAdd','MasVnrArea','BsmtFinSF1','BsmtFinSF2','BsmtUnfSF','TotalBsmtSF','1stFlrSF','2ndFlrSF','LowQualFinSF','GrLivArea','BsmtFullBath',
                'BsmtHalfBath','FullBath','HalfBath','Bedroom','Kitchen','TotRmsAbvGrd','Fireplaces','GarageYrBlt','GarageCars','GarageArea','WoodDeckSF',
                'OpenPorchSF','EnclosedPorch','3SsnPorch','ScreenPorch','PoolArea','MiscVal','YrSold']

# %%
i=1
for col in features:
        print("Including "+str(i)+": "+str(col))
        i+=1
        consider.append(col)
        if col not in numerics:
                le = preprocessing.LabelEncoder()
                train_df[col] = train_df[col].fillna("Missing")
                train_df[col] = le.fit_transform(train_df[col])
        else:
                train_df[col] = train_df[col].fillna(0)

        train = train_df[consider]
        X = train.values
        Y = train_y.values

        log_regressor = linear_model.LinearRegression()
        score2 = cross_val_score(log_regressor,X,Y,cv=5)
        print ("lin_reg: mean="+str(np.mean(score2))+" std="+str(np.std(score2)))
# Out:
# Including 1: MSSubClass
# lin_reg: mean=-0.0017263571493072228 std=0.006786169777736936
# Including 2: MSZoning
# lin_reg: mean=0.025286801800187365 std=0.013167230959064281
# Including 3: LotFrontage
# lin_reg: mean=0.061625246216815824 std=0.028935162304914972
# Including 4: LotArea
# lin_reg: mean=0.0920169878237413 std=0.05978020735163914
# Including 5: Street
# lin_reg: mean=0.10780816623938341 std=0.049525670299022245
# Including 6: Alley
# lin_reg: mean=0.10882994432395421 std=0.04913317418424939
# Including 7: LotShape
# lin_reg: mean=0.17249550458956414 std=0.02911698260681775
# Including 8: LandContour
# lin_reg: mean=0.1758306121979547 std=0.023094046415915524
# Including 9: Utilities
# lin_reg: mean=0.17574600983056965 std=0.023135320382451807
# Including 10: LotConfig
# lin_reg: mean=0.17466193080516487 std=0.02283406989800959
# Including 11: LandSlope
# lin_reg: mean=0.17380987993254907 std=0.024509185817424103
# Including 12: Neighborhood
# lin_reg: mean=0.1937735921951511 std=0.025340895450528835
# Including 13: Condition1
# lin_reg: mean=0.19981275685581862 std=0.023424724370941778
# Including 14: Condition2
# lin_reg: mean=0.1989821047061007 std=0.02326042447332401
# Including 15: BldgType
# lin_reg: mean=0.19758610746731448 std=0.024152824759275517
# Including 16: HouseStyle
# lin_reg: mean=0.22027125303340517 std=0.036635582011176004
# Including 17: OverallQual
# lin_reg: mean=0.6686341810434436 std=0.032824583242764035
# Including 18: OverallCond
# lin_reg: mean=0.6679347715607801 std=0.03313620169659799
# Including 19: YearBuilt
# lin_reg: mean=0.6789925925927973 std=0.037827472501649334
# Including 20: YearRemodAdd
# lin_reg: mean=0.6808342028293495 std=0.04001654267447102
# Including 21: RoofStyle
# lin_reg: mean=0.6882984239516278 std=0.03693660196198566
# Including 22: RoofMatl
# lin_reg: mean=0.6897421389776648 std=0.03709228730921021
# Including 23: Exterior1st
# lin_reg: mean=0.6907231765521591 std=0.03579091661839146
# Including 24: Exterior2nd
# lin_reg: mean=0.6902962326030646 std=0.036802171207152436
# Including 25: MasVnrType
# lin_reg: mean=0.6893533338685043 std=0.03672737786019096
# Including 26: MasVnrArea
# lin_reg: mean=0.7139160721401201 std=0.03903281579843221
# Including 27: ExterQual
# lin_reg: mean=0.7294365652233251 std=0.04497229047542961
# Including 28: ExterCond
# lin_reg: mean=0.7294231862078329 std=0.045240939102328535
# Including 29: Foundation
# lin_reg: mean=0.72998921004332 std=0.04515626992349712
# Including 30: BsmtQual
# lin_reg: mean=0.7361598988037138 std=0.04132005581486481
# Including 31: BsmtCond
# lin_reg: mean=0.7359008620180888 std=0.04112878465292279
# Including 32: BsmtExposure
# lin_reg: mean=0.7373922542939813 std=0.03987843687560049
# Including 33: BsmtFinType1
# lin_reg: mean=0.7413515772975099 std=0.043027566850063564
# Including 34: BsmtFinSF1
# lin_reg: mean=0.7460093376636739 std=0.056901838758444935
# Including 35: BsmtFinType2
# lin_reg: mean=0.7463741108732415 std=0.0576972527476654
# Including 36: BsmtFinSF2
# lin_reg: mean=0.7471366276924024 std=0.0588596676161467
# Including 37: BsmtUnfSF
# lin_reg: mean=0.7524602088522322 std=0.07282919311940955
# Including 38: TotalBsmtSF
# lin_reg: mean=0.7524602088522385 std=0.07282919311943388
# Including 39: Heating
# lin_reg: mean=0.7519162821790942 std=0.07363366289040194
# Including 40: HeatingQC
# lin_reg: mean=0.7529220358217856 std=0.07323363852013848
# Including 41: CentralAir
# lin_reg: mean=0.7525523527986844 std=0.07291767684870311
# Including 42: Electrical
# lin_reg: mean=0.7525282462693907 std=0.07290069368372731
# Including 43: 1stFlrSF
# lin_reg: mean=0.7626651696364419 std=0.07058049589400445
# Including 44: 2ndFlrSF
# lin_reg: mean=0.7970313480778637 std=0.07431599841982206
# Including 45: LowQualFinSF
# lin_reg: mean=0.7967229942612049 std=0.07419155475134447
# Including 46: GrLivArea
# lin_reg: mean=0.7967229942612044 std=0.07419155475133803
# Including 47: BsmtFullBath
# lin_reg: mean=0.7973826748653731 std=0.07290489373811421
# Including 48: BsmtHalfBath
# lin_reg: mean=0.7970263098795628 std=0.07321118171159886
# Including 49: FullBath
# lin_reg: mean=0.795350981160922 std=0.07434216739881089
# Including 50: HalfBath
# lin_reg: mean=0.7957200649351319 std=0.07456224897661527
# Including 51: BedroomAbvGr
# lin_reg: mean=0.795502468662169 std=0.07706295388427473
# Including 52: KitchenAbvGr
# lin_reg: mean=0.7949623436083189 std=0.07812561074280566
# Including 53: KitchenQual
# lin_reg: mean=0.8000702262876842 std=0.07647322214139053
# Including 54: TotRmsAbvGrd
# lin_reg: mean=0.8020935662651603 std=0.07752236173891479
# Including 55: Functional
# lin_reg: mean=0.8045603017873619 std=0.07709719582393387
# Including 56: Fireplaces
# lin_reg: mean=0.8068486076856554 std=0.07634571256991005
# Including 57: FireplaceQu
# lin_reg: mean=0.8068328039264152 std=0.07566997756529378
# Including 58: GarageType
# lin_reg: mean=0.8054853706935059 std=0.07805983271993093
# Including 59: GarageYrBlt
# lin_reg: mean=0.8058028735018148 std=0.0777792669372227
# Including 60: GarageFinish
# lin_reg: mean=0.8056095801660155 std=0.07727483205178169
# Including 61: GarageCars
# lin_reg: mean=0.8125412854100784 std=0.07149043956926836
# Including 62: GarageArea
# lin_reg: mean=0.8109109544553872 std=0.07417151992291304
# Including 63: GarageQual
# lin_reg: mean=0.8107586431346423 std=0.07406498000933731
# Including 64: GarageCond
# lin_reg: mean=0.8108185930045838 std=0.0740334008216856
# Including 65: PavedDrive
# lin_reg: mean=0.810979462516373 std=0.07439319765310069
# Including 66: WoodDeckSF
# lin_reg: mean=0.8112203661519095 std=0.07393489863899054
# Including 67: OpenPorchSF
# lin_reg: mean=0.8107652412464811 std=0.07403818802446226
# Including 68: EnclosedPorch
# lin_reg: mean=0.8106459286335277 std=0.07398776650196398
# Including 69: 3SsnPorch
# lin_reg: mean=0.8101409030313128 std=0.07381369705711997
# Including 70: ScreenPorch
# lin_reg: mean=0.8114299176455801 std=0.07435769102916466
# Including 71: PoolArea
# lin_reg: mean=0.8120797394670699 std=0.07344172846711362
# Including 72: PoolQC
# lin_reg: mean=0.7997714085824769 std=0.08283179045465429
# Including 73: Fence
# lin_reg: mean=0.7996181831739692 std=0.08275405821837023
# Including 74: MiscFeature
# lin_reg: mean=0.7996480809700381 std=0.0826088057354228
# Including 75: MiscVal
# lin_reg: mean=0.7987584492909517 std=0.08260130630919096
# Including 76: MoSold
# lin_reg: mean=0.7983414135138834 std=0.08307393682476814
# Including 77: YrSold
# lin_reg: mean=0.7984250079764754 std=0.08295649494000179
# Including 78: SaleType
# lin_reg: mean=0.7980958866135418 std=0.08298003400204573
# Including 79: SaleCondition
# lin_reg: mean=0.8004259784451678 std=0.0832036411646668

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig,ax=plt.subplots()
ax.scatter(train_y,train_df["OverallQual"])
plt.xlabel('SalePrice')
plt.ylabel('OverallQual')
# Out:
# Text(0, 0.5, 'OverallQual')

# %%
from pylab import *
plot(train_y, train_df["OverallQual"])
show()

# %%
import seaborn as sns
sns.heatmap(train_df.corr())

# %%
# Create heatmap
heatmap, xedges, yedges = np.histogram2d(train_y,train_df["OverallQual"] )


# Plot heatmap
plt.clf()
plt.title('Pythonspot.com heatmap example')
plt.ylabel('y')
plt.xlabel('x')
plt.imshow(heatmap, extent=extent)
plt.show()
